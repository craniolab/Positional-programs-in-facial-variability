# %%
import scanpy as sc
import pandas as pd
import random
import matplotlib as mpl
import numpy as np
import os
from scipy.spatial import distance

import matplotlib
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib.colors import LinearSegmentedColormap, ListedColormap
from matplotlib.lines import Line2D 

import warnings
warnings.filterwarnings('ignore')

from copy import copy
reds = copy(mpl.cm.Reds)
reds.set_under("lightgray")

project_directory = '/Cranio_Lab/Louk_Seton/mesenchyme_project_2023'
os.chdir(os.path.expanduser("~")+project_directory)

# %%
adata = sc.read('anndata_objects/interactive/mesen_all.h5ad')
adata.X = adata.layers['original_counts'].copy()
sc.pp.normalize_total(adata, target_sum=10000)
sc.pp.log1p(adata)

# %%
xl_file = pd.ExcelFile('Supplementary Table 4 - Genes used for AUCell analysis.xlsx')

dfs = {sheet_name: xl_file.parse(sheet_name) 
          for sheet_name in xl_file.sheet_names}

# %%
dfs['EFO_0007841_0.1'].index = list(dfs['EFO_0007841_0.1']['targetId'])
del dfs['EFO_0007841_0.1']['Unnamed: 0']

# %%
gene_list_org = dfs['EFO_0007841_0.1']

# %%
lmd_result = pd.read_csv('r_lmd_result.txt',index_col = 0)
lmd_result.rename({'score':'LMD_score'}, axis=1, inplace=True)
gene_list_all = dfs['EFO_0007841_0.1'].merge(lmd_result, how = 'left',left_index=True, right_index=True)
del gene_list_all['rank']

# %%
gene_list_all
# Out:
#         targetId  variantRsId        studyId     score  \
# Pik3r1    Pik3r1   rs57106444  GCST011429_25  0.489355
# Hmga2      Hmga2    rs7966340   GCST90026542  0.851618
# Hmga2      Hmga2   rs10878346   GCST90044778  0.862497
# Zeb2        Zeb2  rs148912137   GCST90007187  0.504181
# Hmga2      Hmga2    rs7966340   GCST90026541  0.850571
# ...          ...          ...            ...       ...
# Alx4        Alx4   rs10838269   GCST90007273  0.663373
# Creb3l2  Creb3l2    rs6948022   GCST90007303  0.846874
# Efemp1    Efemp1    rs1367228   GCST90007273  0.835481
# Plpp3      Plpp3   rs35622381   GCST90007273  0.142420
# Bcl11b    Bcl11b    rs1257585   GCST90007299  0.513367
#
#         diseaseFromSourceMappedId  LMD_score
# Pik3r1                EFO_0007841   4.735931
# Hmga2                 EFO_0007841        NaN
# Hmga2                 EFO_0007841        NaN
# Zeb2                  EFO_0007841   3.009557
# Hmga2                 EFO_0007841        NaN
# ...                           ...        ...
# Alx4                  EFO_0010949   4.726264
# Creb3l2               EFO_0010949   4.572417
# Efemp1                EFO_0010949   4.397324
# Plpp3                 EFO_0010949   4.854394
# Bcl11b                EFO_0010949   3.698835
#
# [273 rows x 6 columns]

# %%
sc.tl.rank_genes_groups(adata,groupby = 'annotation_all',
                        method = 'wilcoxon',
                       )

# %%
rank_genes_df = sc.get.rank_genes_groups_df(adata, group = None)
rank_genes_df = rank_genes_df[rank_genes_df['names'].isin(list(set(gene_list_all['targetId'])))]
rank_genes_df = rank_genes_df[~rank_genes_df['scores'].between(-4, 4)]
rank_genes_df = rank_genes_df.pivot(index='names', columns='group', values=['logfoldchanges'])
for gene in list(set(gene_list_org['targetId']).difference(list(rank_genes_df.index))):
    rank_genes_df.loc[gene] = pd.Series(dtype='float64')

rank_genes_df.columns = rank_genes_df.columns.droplevel()

expanded_table = {'all_cells':gene_list_all.merge(rank_genes_df, left_index=True, right_index=True)}


expanded_table['all_cells'].insert(loc=5, column='Top Cluster', value=list(expanded_table['all_cells'].iloc[:,6:].idxmax(axis=1,skipna=True)))
expanded_table['all_cells']
# Out:
#         targetId  variantRsId        studyId     score  \
# Pik3r1    Pik3r1   rs57106444  GCST011429_25  0.489355
# Hmga2      Hmga2    rs7966340   GCST90026542  0.851618
# Hmga2      Hmga2   rs10878346   GCST90044778  0.862497
# Zeb2        Zeb2  rs148912137   GCST90007187  0.504181
# Hmga2      Hmga2    rs7966340   GCST90026541  0.850571
# ...          ...          ...            ...       ...
# Alx4        Alx4   rs10838269   GCST90007273  0.663373
# Creb3l2  Creb3l2    rs6948022   GCST90007303  0.846874
# Efemp1    Efemp1    rs1367228   GCST90007273  0.835481
# Plpp3      Plpp3   rs35622381   GCST90007273  0.142420
# Bcl11b    Bcl11b    rs1257585   GCST90007299  0.513367
#
#         diseaseFromSourceMappedId                    Top Cluster  LMD_score  \
# Pik3r1                EFO_0007841                  Perichondrium   4.735931
# Hmga2                 EFO_0007841                          MXP 3        NaN
# Hmga2                 EFO_0007841                          MXP 3        NaN
# Zeb2                  EFO_0007841                    Roof - Sim1   3.009557
# Hmga2                 EFO_0007841                          MXP 3        NaN
# ...                           ...                            ...        ...
# Alx4                  EFO_0010949                    LnP - Casz1   4.726264
# Creb3l2               EFO_0010949  Chondrocytes - Septum/Capsule   4.572417
# Efemp1                EFO_0010949                Lip Fibroblasts   4.397324
# Plpp3                 EFO_0010949                Lip Fibroblasts   4.854394
# Bcl11b                EFO_0010949                    Whisker Pad   3.698835
#
#          Neural Crest  MXP Early  MXP Early 2  ...  Lip - Dermal  \
# Pik3r1      -2.658116  -2.627492    -2.948618  ...     -0.931847
# Hmga2       -0.782482  -0.841932          NaN  ...      1.159314
# Hmga2       -0.782482  -0.841932          NaN  ...      1.159314
# Zeb2              NaN  -2.322127    -4.138664  ...      0.521783
# Hmga2       -0.782482  -0.841932          NaN  ...      1.159314
# ...               ...        ...          ...  ...           ...
# Alx4        -4.504507  -5.177282    -2.515970  ...     -0.765742
# Creb3l2     -3.288305  -3.221023    -2.618737  ...     -0.376792
# Efemp1     -26.972183  -4.876045    -4.704730  ...      1.456605
# Plpp3       -4.770107  -3.188590    -1.164912  ...           NaN
# Bcl11b      -9.039378  -7.800635    -2.438078  ...      1.360745
#
#          Lip Fibroblasts  Lip-Nostril Fusion  Nostrils - Gata2  \
# Pik3r1               NaN                 NaN               NaN
# Hmga2          -0.392486           -1.041206               NaN
# Hmga2          -0.392486           -1.041206               NaN
# Zeb2            0.339233            0.900199         -0.754061
# Hmga2          -0.392486           -1.041206               NaN
# ...                  ...                 ...               ...
# Alx4                 NaN            0.585752               NaN
# Creb3l2              NaN                 NaN         -0.652480
# Efemp1          1.798812           -1.444790               NaN
# Plpp3           1.074637            0.313572         -0.698780
# Bcl11b          1.890989                 NaN          1.406687
#
#          Nostrils - Pax7  Nostrils - Tfap2b  Philtrum  Roof - Sim1  \
# Pik3r1               NaN          -0.847520  1.100682     0.513304
# Hmga2          -1.512490          -0.580599 -1.828394     0.371909
# Hmga2          -1.512490          -0.580599 -1.828394     0.371909
# Zeb2            1.216569          -0.319992  1.190975     2.762205
# Hmga2          -1.512490          -0.580599 -1.828394     0.371909
# ...                  ...                ...       ...          ...
# Alx4                 NaN           0.946143  1.300044          NaN
# Creb3l2              NaN          -0.733441       NaN          NaN
# Efemp1               NaN                NaN       NaN     1.105140
# Plpp3           0.589165                NaN  0.721816     0.329927
# Bcl11b          1.519184           0.203697 -0.574491     1.499182
#
#          Whisker Pad  Periocular Mesenchyme
# Pik3r1     -0.928966                    NaN
# Hmga2       0.304483                    NaN
# Hmga2       0.304483                    NaN
# Zeb2        1.734469                    NaN
# Hmga2       0.304483                    NaN
# ...              ...                    ...
# Alx4        0.497647                    NaN
# Creb3l2    -0.729403                    NaN
# Efemp1      1.255099               0.813366
# Plpp3       0.113914                    NaN
# Bcl11b      2.005512              -0.436476
#
# [273 rows x 60 columns]

# %%
for stage in list(adata.obs['stage'].cat.categories):
    adata_tmp = adata[adata.obs['stage']==stage]
    adata_tmp = adata_tmp[adata_tmp.obs['annotation_all'].isin(list(adata_tmp.obs['annotation_all'].value_counts()[adata_tmp.obs['annotation_all'].value_counts()>20].index))]
    sc.tl.rank_genes_groups(adata_tmp,groupby = 'annotation_all',
                        method = 'wilcoxon',
                       )
    rank_genes_df = sc.get.rank_genes_groups_df(adata_tmp, group = None)
    rank_genes_df = rank_genes_df[rank_genes_df['names'].isin(list(set(gene_list_org['targetId'])))]
    rank_genes_df = rank_genes_df[~rank_genes_df['scores'].between(-4, 4)]
    rank_genes_df = rank_genes_df.pivot(index='names', columns='group', values=['logfoldchanges'])
    for gene in list(set(gene_list_org['targetId']).difference(list(rank_genes_df.index))):
        rank_genes_df.loc[gene] = pd.Series(dtype='float64')
    rank_genes_df.columns = rank_genes_df.columns.droplevel()
    
    lmd_result = pd.read_csv('r_lmd_result_E'+stage+'.txt',index_col = 0)
    lmd_result.rename({'score':'LMD_score'}, axis=1, inplace=True)
    gene_list_stage = gene_list_org.merge(lmd_result, how = 'left',left_index=True, right_index=True)
    del gene_list_stage['rank']
    expanded_table[stage] = gene_list_stage.merge(rank_genes_df, left_index=True, right_index=True)

for stage in list(adata.obs['stage'].cat.categories):
    expanded_table[stage].insert(loc=5, column='Top Cluster', value=list(expanded_table[stage].iloc[:,6:].idxmax(axis=1,skipna=True)))

# %%
with pd.ExcelWriter("GWAS/gwas_table_expanded_LMD.xlsx") as writer:
    for df_name, df in expanded_table.items():
        df.to_excel(writer, sheet_name=df_name)

# %%
xl_file = pd.ExcelFile('Supplementary Table 4 - Genes used for AUCell analysis.xlsx')

dfs = {sheet_name: xl_file.parse(sheet_name) 
          for sheet_name in xl_file.sheet_names}

# %%
dfs['disgenet'].index = list(dfs['disgenet']['mouse_gene'])
del dfs['disgenet']['mouse_gene']

# %%
gene_list_org = dfs['disgenet']

# %%
lmd_result = pd.read_csv('r_lmd_result.txt',index_col = 0)
lmd_result.rename({'score':'LMD_score'}, axis=1, inplace=True)
gene_list_all = dfs['disgenet'].merge(lmd_result, how = 'left',left_index=True, right_index=True)
del gene_list_all['rank']

# %%
gene_list_all
# Out:
#        gene_symbol  numVariantsAssociatedToGene                disease_name  \
# Irf6          IRF6                          153             Cleft upper lip
# Irf6          IRF6                          153             Cleft upper lip
# Irf6          IRF6                          153                Cleft Palate
# Irf6          IRF6                          153             Cleft upper lip
# Irf6          IRF6                          153             Cleft upper lip
# ...            ...                          ...                         ...
# Trp63         TP63                          167  Craniofacial Abnormalities
# Thrb          THRB                          188  Craniofacial Abnormalities
# Col2a1      COL2A1                          378  Craniofacial Abnormalities
# Dlx1          DLX1                            0  Craniofacial Abnormalities
# Hoxa3        HOXA3                            8  Craniofacial Abnormalities
#
#               pmid   geneEnsemblIDs  LMD_score
# Irf6    20436469.0  ENSG00000117595   4.554414
# Irf6    18836445.0  ENSG00000117595   4.554414
# Irf6    17041601.0  ENSG00000117595   4.554414
# Irf6    17041601.0  ENSG00000117595   4.554414
# Irf6           NaN  ENSG00000117595   4.554414
# ...            ...              ...        ...
# Trp63   10227294.0  ENSG00000073282   4.738057
# Thrb    10660344.0  ENSG00000151090   4.226990
# Col2a1   9061443.0  ENSG00000139219   2.523620
# Dlx1     9187081.0  ENSG00000144355   2.972744
# Hoxa3    1673020.0  ENSG00000105997   4.246604
#
# [174 rows x 6 columns]

# %%
sc.tl.rank_genes_groups(adata,groupby = 'annotation_all',
                        method = 'wilcoxon',
                       )

# %%
rank_genes_df = sc.get.rank_genes_groups_df(adata, group = None)
rank_genes_df = rank_genes_df[rank_genes_df['names'].isin(list(set(gene_list_all.index)))]
rank_genes_df = rank_genes_df[~rank_genes_df['scores'].between(-4, 4)]
rank_genes_df = rank_genes_df.pivot(index='names', columns='group', values=['logfoldchanges'])
for gene in list(set(gene_list_all.index).difference(list(rank_genes_df.index))):
    rank_genes_df.loc[gene] = pd.Series(dtype='float64')

rank_genes_df.columns = rank_genes_df.columns.droplevel()

expanded_table = {'all_cells':gene_list_all.merge(rank_genes_df, left_index=True, right_index=True)}


expanded_table['all_cells'].insert(loc=5, column='Top Cluster', value=list(expanded_table['all_cells'].iloc[:,6:].idxmax(axis=1,skipna=True)))
expanded_table['all_cells']
# Out:
#        gene_symbol  numVariantsAssociatedToGene                disease_name  \
# Irf6          IRF6                          153             Cleft upper lip
# Irf6          IRF6                          153             Cleft upper lip
# Irf6          IRF6                          153                Cleft Palate
# Irf6          IRF6                          153             Cleft upper lip
# Irf6          IRF6                          153             Cleft upper lip
# ...            ...                          ...                         ...
# Trp63         TP63                          167  Craniofacial Abnormalities
# Thrb          THRB                          188  Craniofacial Abnormalities
# Col2a1      COL2A1                          378  Craniofacial Abnormalities
# Dlx1          DLX1                            0  Craniofacial Abnormalities
# Hoxa3        HOXA3                            8  Craniofacial Abnormalities
#
#               pmid   geneEnsemblIDs                    Top Cluster  LMD_score  \
# Irf6    20436469.0  ENSG00000117595                            NaN   4.554414
# Irf6    18836445.0  ENSG00000117595                            NaN   4.554414
# Irf6    17041601.0  ENSG00000117595                            NaN   4.554414
# Irf6    17041601.0  ENSG00000117595                            NaN   4.554414
# Irf6           NaN  ENSG00000117595                            NaN   4.554414
# ...            ...              ...                            ...        ...
# Trp63   10227294.0  ENSG00000073282                            NaN   4.738057
# Thrb    10660344.0  ENSG00000151090         Nasal Cavity - Ventral   4.226990
# Col2a1   9061443.0  ENSG00000139219  Chondrocytes - Septum/Capsule   2.523620
# Dlx1     9187081.0  ENSG00000144355                          Molar   2.972744
# Hoxa3    1673020.0  ENSG00000105997                            NaN   4.246604
#
#         Neural Crest  MXP Early  MXP Early 2  ...  Lip - Dermal  \
# Irf6             NaN        NaN          NaN  ...           NaN
# Irf6             NaN        NaN          NaN  ...           NaN
# Irf6             NaN        NaN          NaN  ...           NaN
# Irf6             NaN        NaN          NaN  ...           NaN
# Irf6             NaN        NaN          NaN  ...           NaN
# ...              ...        ...          ...  ...           ...
# Trp63            NaN        NaN          NaN  ...           NaN
# Thrb             NaN        NaN          NaN  ...           NaN
# Col2a1     -2.492457  -1.276198     0.057825  ...     -1.464558
# Dlx1             NaN   2.037174     3.222830  ...      2.116504
# Hoxa3            NaN        NaN          NaN  ...           NaN
#
#         Lip Fibroblasts  Lip-Nostril Fusion  Nostrils - Gata2  \
# Irf6                NaN                 NaN               NaN
# Irf6                NaN                 NaN               NaN
# Irf6                NaN                 NaN               NaN
# Irf6                NaN                 NaN               NaN
# Irf6                NaN                 NaN               NaN
# ...                 ...                 ...               ...
# Trp63               NaN                 NaN               NaN
# Thrb                NaN                 NaN               NaN
# Col2a1        -1.347652           -1.759115         -2.329834
# Dlx1                NaN           -3.492601               NaN
# Hoxa3               NaN                 NaN               NaN
#
#         Nostrils - Pax7  Nostrils - Tfap2b  Philtrum  Roof - Sim1  \
# Irf6                NaN                NaN       NaN          NaN
# Irf6                NaN                NaN       NaN          NaN
# Irf6                NaN                NaN       NaN          NaN
# Irf6                NaN                NaN       NaN          NaN
# Irf6                NaN                NaN       NaN          NaN
# ...                 ...                ...       ...          ...
# Trp63               NaN                NaN       NaN          NaN
# Thrb                NaN                NaN       NaN     1.461677
# Col2a1        -2.486367          -2.131100 -1.417586    -1.637389
# Dlx1                NaN          -3.118024       NaN    -3.524400
# Hoxa3               NaN                NaN       NaN          NaN
#
#         Whisker Pad  Periocular Mesenchyme
# Irf6            NaN                    NaN
# Irf6            NaN                    NaN
# Irf6            NaN                    NaN
# Irf6            NaN                    NaN
# Irf6            NaN                    NaN
# ...             ...                    ...
# Trp63           NaN                    NaN
# Thrb            NaN                    NaN
# Col2a1    -1.513544              -1.605205
# Dlx1            NaN                    NaN
# Hoxa3           NaN                    NaN
#
# [174 rows x 60 columns]

# %%
for stage in list(adata.obs['stage'].cat.categories):
    adata_tmp = adata[adata.obs['stage']==stage]
    adata_tmp = adata_tmp[adata_tmp.obs['annotation_all'].isin(list(adata_tmp.obs['annotation_all'].value_counts()[adata_tmp.obs['annotation_all'].value_counts()>20].index))]
    sc.tl.rank_genes_groups(adata_tmp,groupby = 'annotation_all',
                        method = 'wilcoxon',
                       )
    rank_genes_df = sc.get.rank_genes_groups_df(adata_tmp, group = None)
    rank_genes_df = rank_genes_df[rank_genes_df['names'].isin(list(set(gene_list_all.index)))]
    rank_genes_df = rank_genes_df[~rank_genes_df['scores'].between(-4, 4)]
    rank_genes_df = rank_genes_df.pivot(index='names', columns='group', values=['logfoldchanges'])
    for gene in list(set(gene_list_all.index).difference(list(rank_genes_df.index))):
        rank_genes_df.loc[gene] = pd.Series(dtype='float64')
    rank_genes_df.columns = rank_genes_df.columns.droplevel()
    
    lmd_result = pd.read_csv('r_lmd_result_E'+stage+'.txt',index_col = 0)
    lmd_result.rename({'score':'LMD_score'}, axis=1, inplace=True)
    gene_list_stage = gene_list_org.merge(lmd_result, how = 'left',left_index=True, right_index=True)
    del gene_list_stage['rank']
    expanded_table[stage] = gene_list_stage.merge(rank_genes_df, left_index=True, right_index=True)

for stage in list(adata.obs['stage'].cat.categories):
    expanded_table[stage].insert(loc=5, column='Top Cluster', value=list(expanded_table[stage].iloc[:,6:].idxmax(axis=1,skipna=True)))

# %%
with pd.ExcelWriter("GWAS/gwas_table_disgenet_expanded_LMD.xlsx") as writer:
    for df_name, df in expanded_table.items():
        df.to_excel(writer, sheet_name=df_name)

# %%
from math import ceil
from kneed import KneeLocator

lmd_result = pd.read_csv('r_lmd_result.txt',index_col = 0)
kneedle = KneeLocator(lmd_result['rank'], lmd_result['score'], S=2.5, curve="concave", direction="increasing")
ax = lmd_result.plot.scatter(x = 'rank',y = 'score', s = 1)
plt.axhline(y=kneedle.knee_y, color='r', linestyle='-')
plt.axvline(x=kneedle.knee, color='r', linestyle='-')
plt.title('all cells - knee: '+str(kneedle.knee)+' , '+str(ceil(kneedle.knee_y * 1000) / 1000.0))

plt.savefig('GWAS/lmd_all_cells.svg')
plt.close()

for stage in list(adata.obs['stage'].cat.categories):
    lmd_result = pd.read_csv('r_lmd_result_E'+stage+'.txt',index_col = 0)
    kneedle = KneeLocator(lmd_result['rank'], lmd_result['score'], S=2.5, curve="concave", direction="increasing")
    ax = lmd_result.plot.scatter(x = 'rank',y = 'score', s = 1)
    plt.axhline(y=kneedle.knee_y, color='r', linestyle='-')
    plt.axvline(x=kneedle.knee, color='r', linestyle='-')
    plt.title('E'+stage+' - knee: '+str(kneedle.knee)+' , '+str(ceil(kneedle.knee_y * 1000) / 1000.0))
    plt.savefig('GWAS/lmd_E'+stage+'.svg')
    plt.close()

# %%
xl_file = pd.ExcelFile('Supplementary Table 4 - Genes used for AUCell analysis.xlsx')

dfs = {sheet_name: xl_file.parse(sheet_name) 
          for sheet_name in xl_file.sheet_names}

# %%
dfs['MGI_prominences'].index = list(dfs['MGI_prominences']['Marker Symbol'])

# %%
gene_list_org = dfs['MGI_prominences']

# %%
lmd_result = pd.read_csv('r_lmd_result.txt',index_col = 0)
lmd_result.rename({'score':'LMD_score'}, axis=1, inplace=True)
gene_list_all = dfs['MGI_prominences'].merge(lmd_result, how = 'left',left_index=True, right_index=True)
del gene_list_all['rank']

# %%
gene_list_all
# Out:
#         MGI Marker Accession ID Marker Symbol Mammalian Phenotype ID  \
# Dlx5                 MGI:101926          Dlx5             MP:0009902
# Dlx5                 MGI:101926          Dlx5             MP:0030250
# Aldh1a2              MGI:107928       Aldh1a2             MP:0030249
# Pax6                  MGI:97490          Pax6             MP:0009902
# Pax6                  MGI:97490          Pax6             MP:0009903
# Hesx1                 MGI:96071         Hesx1             MP:0009901
# Pdgfra                MGI:97530        Pdgfra             MP:0009901
# Sp8                 MGI:2443471           Sp8             MP:0009902
# Sp8                 MGI:2443471           Sp8             MP:0009903
# Sp8                 MGI:2443471           Sp8             MP:0010940
# Shh                   MGI:98297           Shh             MP:0009901
# Edil3               MGI:1329025         Edil3             MP:0009901
# Shh                   MGI:98297           Shh             MP:0010940
# Shh                   MGI:98297           Shh             MP:0030250
# Dkk1                MGI:1329040          Dkk1             MP:0012178
# Dlx5                 MGI:101926          Dlx5             MP:0009901
# Gas1                  MGI:95655          Gas1             MP:0009903
# Otx2                  MGI:97451          Otx2             MP:0010940
# Ndst3               MGI:1932544         Ndst3             MP:0010940
# Ndst3               MGI:1932544         Ndst3             MP:0030250
# Shh                   MGI:98297           Shh             MP:0009903
# Six3                 MGI:102764          Six3             MP:0009903
# Hesx1                 MGI:96071         Hesx1             MP:0012178
# Rdh10               MGI:1924238         Rdh10             MP:0009901
# Rdh10               MGI:1924238         Rdh10             MP:0009902
# Rdh10               MGI:1924238         Rdh10             MP:0009903
# Rdh10               MGI:1924238         Rdh10             MP:0010940
# Rdh10               MGI:1924238         Rdh10             MP:0030250
# Aldh1a2              MGI:107928       Aldh1a2             MP:0010940
# Ptch1                MGI:105373         Ptch1             MP:0010940
# Cldn6               MGI:1859284         Cldn6             MP:0009901
# Foxg1               MGI:1347464         Foxg1             MP:0009901
# Hand1                MGI:103577         Hand1             MP:0010940
# Tfap2a               MGI:104671        Tfap2a             MP:0009902
# Tfap2a               MGI:104671        Tfap2a             MP:0009903
# Tfap2a               MGI:104671        Tfap2a             MP:0010940
# Foxg1               MGI:1347464         Foxg1             MP:0030250
# Fgfr2                 MGI:95523         Fgfr2             MP:0030250
# Alx1                 MGI:104621          Alx1             MP:0009902
# Alx4                 MGI:108359          Alx4             MP:0009902
# Alx4                 MGI:108359          Alx4             MP:0009903
# Alx1                 MGI:104621          Alx1             MP:0009903
# Fgfr1                 MGI:95522         Fgfr1             MP:0030249
# Fgfr1                 MGI:95522         Fgfr1             MP:0009903
# Esrp1               MGI:1917326         Esrp1             MP:0009902
# Esrp1               MGI:1917326         Esrp1             MP:0009903
#
#          LMD_score
# Dlx5      3.922977
# Dlx5      3.922977
# Aldh1a2   3.104074
# Pax6      4.854568
# Pax6      4.854568
# Hesx1     4.167228
# Pdgfra    5.172327
# Sp8       4.822944
# Sp8       4.822944
# Sp8       4.822944
# Shh       4.377033
# Edil3     4.388556
# Shh       4.377033
# Shh       4.377033
# Dkk1      3.093461
# Dlx5      3.922977
# Gas1           NaN
# Otx2      4.935095
# Ndst3     3.981703
# Ndst3     3.981703
# Shh       4.377033
# Six3      5.060815
# Hesx1     4.167228
# Rdh10     5.094263
# Rdh10     5.094263
# Rdh10     5.094263
# Rdh10     5.094263
# Rdh10     5.094263
# Aldh1a2   3.104074
# Ptch1     4.257479
# Cldn6     4.946561
# Foxg1     4.672194
# Hand1          NaN
# Tfap2a    4.089263
# Tfap2a    4.089263
# Tfap2a    4.089263
# Foxg1     4.672194
# Fgfr2     4.514869
# Alx1      3.310950
# Alx4      4.726264
# Alx4      4.726264
# Alx1      3.310950
# Fgfr1          NaN
# Fgfr1          NaN
# Esrp1     4.857848
# Esrp1     4.857848

# %%
sc.tl.rank_genes_groups(adata,groupby = 'annotation_all',
                        method = 'wilcoxon',
                       )

# %%
rank_genes_df = sc.get.rank_genes_groups_df(adata, group = None)
rank_genes_df = rank_genes_df[rank_genes_df['names'].isin(list(set(gene_list_all['Marker Symbol'])))]
rank_genes_df = rank_genes_df[~rank_genes_df['scores'].between(-4, 4)]
rank_genes_df = rank_genes_df.pivot(index='names', columns='group', values=['logfoldchanges'])
for gene in list(set(gene_list_org['Marker Symbol']).difference(list(rank_genes_df.index))):
    rank_genes_df.loc[gene] = pd.Series(dtype='float64')

rank_genes_df.columns = rank_genes_df.columns.droplevel()

expanded_table = {'all_cells':gene_list_all.merge(rank_genes_df, left_index=True, right_index=True)}


expanded_table['all_cells'].insert(loc=3, column='Top Cluster', value=list(expanded_table['all_cells'].iloc[:,4:].idxmax(axis=1,skipna=True)))
expanded_table['all_cells']
# Out:
#         MGI Marker Accession ID Marker Symbol Mammalian Phenotype ID  \
# Dlx5                 MGI:101926          Dlx5             MP:0009902
# Dlx5                 MGI:101926          Dlx5             MP:0030250
# Aldh1a2              MGI:107928       Aldh1a2             MP:0030249
# Pax6                  MGI:97490          Pax6             MP:0009902
# Pax6                  MGI:97490          Pax6             MP:0009903
# Hesx1                 MGI:96071         Hesx1             MP:0009901
# Pdgfra                MGI:97530        Pdgfra             MP:0009901
# Sp8                 MGI:2443471           Sp8             MP:0009902
# Sp8                 MGI:2443471           Sp8             MP:0009903
# Sp8                 MGI:2443471           Sp8             MP:0010940
# Shh                   MGI:98297           Shh             MP:0009901
# Edil3               MGI:1329025         Edil3             MP:0009901
# Shh                   MGI:98297           Shh             MP:0010940
# Shh                   MGI:98297           Shh             MP:0030250
# Dkk1                MGI:1329040          Dkk1             MP:0012178
# Dlx5                 MGI:101926          Dlx5             MP:0009901
# Gas1                  MGI:95655          Gas1             MP:0009903
# Otx2                  MGI:97451          Otx2             MP:0010940
# Ndst3               MGI:1932544         Ndst3             MP:0010940
# Ndst3               MGI:1932544         Ndst3             MP:0030250
# Shh                   MGI:98297           Shh             MP:0009903
# Six3                 MGI:102764          Six3             MP:0009903
# Hesx1                 MGI:96071         Hesx1             MP:0012178
# Rdh10               MGI:1924238         Rdh10             MP:0009901
# Rdh10               MGI:1924238         Rdh10             MP:0009902
# Rdh10               MGI:1924238         Rdh10             MP:0009903
# Rdh10               MGI:1924238         Rdh10             MP:0010940
# Rdh10               MGI:1924238         Rdh10             MP:0030250
# Aldh1a2              MGI:107928       Aldh1a2             MP:0010940
# Ptch1                MGI:105373         Ptch1             MP:0010940
# Cldn6               MGI:1859284         Cldn6             MP:0009901
# Foxg1               MGI:1347464         Foxg1             MP:0009901
# Hand1                MGI:103577         Hand1             MP:0010940
# Tfap2a               MGI:104671        Tfap2a             MP:0009902
# Tfap2a               MGI:104671        Tfap2a             MP:0009903
# Tfap2a               MGI:104671        Tfap2a             MP:0010940
# Foxg1               MGI:1347464         Foxg1             MP:0030250
# Fgfr2                 MGI:95523         Fgfr2             MP:0030250
# Alx1                 MGI:104621          Alx1             MP:0009902
# Alx4                 MGI:108359          Alx4             MP:0009902
# Alx4                 MGI:108359          Alx4             MP:0009903
# Alx1                 MGI:104621          Alx1             MP:0009903
# Fgfr1                 MGI:95522         Fgfr1             MP:0030249
# Fgfr1                 MGI:95522         Fgfr1             MP:0009903
# Esrp1               MGI:1917326         Esrp1             MP:0009902
# Esrp1               MGI:1917326         Esrp1             MP:0009903
#
#                            Top Cluster  LMD_score  Neural Crest  MXP Early  \
# Dlx5                        Osteoblast   3.922977           NaN  -3.930424
# Dlx5                        Osteoblast   3.922977           NaN  -3.930424
# Aldh1a2                 MxP Mesenchyme   3.104074     -6.854046  -6.205167
# Pax6                               NaN   4.854568           NaN        NaN
# Pax6                               NaN   4.854568           NaN        NaN
# Hesx1                              NaN   4.167228           NaN        NaN
# Pdgfra                 Lip Fibroblasts   5.172327     -3.052208  -2.813557
# Sp8                                NaN   4.822944           NaN        NaN
# Sp8                                NaN   4.822944           NaN        NaN
# Sp8                                NaN   4.822944           NaN        NaN
# Shh                                NaN   4.377033           NaN        NaN
# Edil3    Chondrocytes - Septum/Capsule   4.388556     -5.208115  -4.164878
# Shh                                NaN   4.377033           NaN        NaN
# Shh                                NaN   4.377033           NaN        NaN
# Dkk1                   Nostrils - Pax7   3.093461     -5.032585  -6.270580
# Dlx5                        Osteoblast   3.922977           NaN  -3.930424
# Gas1                          Philtrum        NaN     -2.785555  -2.440620
# Otx2                               NaN   4.935095           NaN        NaN
# Ndst3                      Whisker Pad   3.981703           NaN        NaN
# Ndst3                      Whisker Pad   3.981703           NaN        NaN
# Shh                                NaN   4.377033           NaN        NaN
# Six3                               NaN   5.060815           NaN        NaN
# Hesx1                              NaN   4.167228           NaN        NaN
# Rdh10                  Nostrils - Pax7   5.094263           NaN  -2.621863
# Rdh10                  Nostrils - Pax7   5.094263           NaN  -2.621863
# Rdh10                  Nostrils - Pax7   5.094263           NaN  -2.621863
# Rdh10                  Nostrils - Pax7   5.094263           NaN  -2.621863
# Rdh10                  Nostrils - Pax7   5.094263           NaN  -2.621863
# Aldh1a2                 MxP Mesenchyme   3.104074     -6.854046  -6.205167
# Ptch1         Palatal Shelf - Anterior   4.257479     -3.351727  -2.244354
# Cldn6                              NaN   4.946561           NaN        NaN
# Foxg1                              NaN   4.672194           NaN        NaN
# Hand1                              NaN        NaN           NaN        NaN
# Tfap2a                     LnP - Casz1   4.089263      1.874989   1.131613
# Tfap2a                     LnP - Casz1   4.089263      1.874989   1.131613
# Tfap2a                     LnP - Casz1   4.089263      1.874989   1.131613
# Foxg1                              NaN   4.672194           NaN        NaN
# Fgfr2                    Perichondrium   4.514869     -3.283917  -3.252742
# Alx1                          Philtrum   3.310950     -3.035843  -2.269296
# Alx4                       LnP - Casz1   4.726264     -4.504507  -5.177282
# Alx4                       LnP - Casz1   4.726264     -4.504507  -5.177282
# Alx1                          Philtrum   3.310950     -3.035843  -2.269296
# Fgfr1                    Perichondrium        NaN     -2.239609  -2.157842
# Fgfr1                    Perichondrium        NaN     -2.239609  -2.157842
# Esrp1                              NaN   4.857848           NaN        NaN
# Esrp1                              NaN   4.857848           NaN        NaN
#
#          MXP Early 2     MXP 1     MXP 2  ...  Lip - Dermal  Lip Fibroblasts  \
# Dlx5             NaN       NaN       NaN  ...     -1.219709              NaN
# Dlx5             NaN       NaN       NaN  ...     -1.219709              NaN
# Aldh1a2          NaN       NaN       NaN  ...     -2.609440              NaN
# Pax6             NaN       NaN       NaN  ...           NaN              NaN
# Pax6             NaN       NaN       NaN  ...           NaN              NaN
# Hesx1            NaN       NaN       NaN  ...           NaN              NaN
# Pdgfra     -2.058467       NaN       NaN  ...      0.177607         0.992973
# Sp8              NaN       NaN       NaN  ...           NaN              NaN
# Sp8              NaN       NaN       NaN  ...           NaN              NaN
# Sp8              NaN       NaN       NaN  ...           NaN              NaN
# Shh              NaN       NaN       NaN  ...           NaN              NaN
# Edil3      -3.019741       NaN       NaN  ...     -1.281487              NaN
# Shh              NaN       NaN       NaN  ...           NaN              NaN
# Shh              NaN       NaN       NaN  ...           NaN              NaN
# Dkk1       -3.516522       NaN       NaN  ...      0.894408              NaN
# Dlx5             NaN       NaN       NaN  ...     -1.219709              NaN
# Gas1       -1.166142 -2.248739       NaN  ...      0.730684         0.993715
# Otx2             NaN       NaN       NaN  ...           NaN              NaN
# Ndst3            NaN       NaN       NaN  ...           NaN              NaN
# Ndst3            NaN       NaN       NaN  ...           NaN              NaN
# Shh              NaN       NaN       NaN  ...           NaN              NaN
# Six3             NaN       NaN       NaN  ...           NaN              NaN
# Hesx1            NaN       NaN       NaN  ...           NaN              NaN
# Rdh10            NaN       NaN       NaN  ...           NaN              NaN
# Rdh10            NaN       NaN       NaN  ...           NaN              NaN
# Rdh10            NaN       NaN       NaN  ...           NaN              NaN
# Rdh10            NaN       NaN       NaN  ...           NaN              NaN
# Rdh10            NaN       NaN       NaN  ...           NaN              NaN
# Aldh1a2          NaN       NaN       NaN  ...     -2.609440              NaN
# Ptch1      -2.040973  0.918329       NaN  ...     -0.335913              NaN
# Cldn6            NaN       NaN       NaN  ...           NaN              NaN
# Foxg1            NaN       NaN       NaN  ...           NaN              NaN
# Hand1            NaN       NaN       NaN  ...           NaN              NaN
# Tfap2a           NaN       NaN       NaN  ...           NaN        -3.033328
# Tfap2a           NaN       NaN       NaN  ...           NaN        -3.033328
# Tfap2a           NaN       NaN       NaN  ...           NaN        -3.033328
# Foxg1            NaN       NaN       NaN  ...           NaN              NaN
# Fgfr2      -2.772741       NaN       NaN  ...           NaN        -0.909870
# Alx1       -2.632683 -3.553479 -5.257678  ...     -1.056710        -1.160158
# Alx4       -2.515970 -3.302193       NaN  ...     -0.765742              NaN
# Alx4       -2.515970 -3.302193       NaN  ...     -0.765742              NaN
# Alx1       -2.632683 -3.553479 -5.257678  ...     -1.056710        -1.160158
# Fgfr1      -1.463229 -0.838416       NaN  ...      0.227000              NaN
# Fgfr1      -1.463229 -0.838416       NaN  ...      0.227000              NaN
# Esrp1            NaN       NaN       NaN  ...           NaN              NaN
# Esrp1            NaN       NaN       NaN  ...           NaN              NaN
#
#          Lip-Nostril Fusion  Nostrils - Gata2  Nostrils - Pax7  \
# Dlx5                    NaN               NaN              NaN
# Dlx5                    NaN               NaN              NaN
# Aldh1a2           -2.602859         -2.594866              NaN
# Pax6                    NaN               NaN              NaN
# Pax6                    NaN               NaN              NaN
# Hesx1                   NaN               NaN              NaN
# Pdgfra                  NaN               NaN              NaN
# Sp8                     NaN               NaN              NaN
# Sp8                     NaN               NaN              NaN
# Sp8                     NaN               NaN              NaN
# Shh                     NaN               NaN              NaN
# Edil3                   NaN               NaN              NaN
# Shh                     NaN               NaN              NaN
# Shh                     NaN               NaN              NaN
# Dkk1               1.864573               NaN         3.407473
# Dlx5                    NaN               NaN              NaN
# Gas1               0.614192         -0.490061         0.817305
# Otx2                    NaN               NaN              NaN
# Ndst3                   NaN               NaN              NaN
# Ndst3                   NaN               NaN              NaN
# Shh                     NaN               NaN              NaN
# Six3                    NaN               NaN              NaN
# Hesx1                   NaN               NaN              NaN
# Rdh10              0.905073               NaN         2.543505
# Rdh10              0.905073               NaN         2.543505
# Rdh10              0.905073               NaN         2.543505
# Rdh10              0.905073               NaN         2.543505
# Rdh10              0.905073               NaN         2.543505
# Aldh1a2           -2.602859         -2.594866              NaN
# Ptch1                   NaN          1.027076        -1.271278
# Cldn6                   NaN               NaN              NaN
# Foxg1                   NaN               NaN              NaN
# Hand1                   NaN               NaN              NaN
# Tfap2a             1.326716          1.244393              NaN
# Tfap2a             1.326716          1.244393              NaN
# Tfap2a             1.326716          1.244393              NaN
# Foxg1                   NaN               NaN              NaN
# Fgfr2                   NaN         -0.971860              NaN
# Alx1               0.910440          0.869685         0.975442
# Alx4               0.585752               NaN              NaN
# Alx4               0.585752               NaN              NaN
# Alx1               0.910440          0.869685         0.975442
# Fgfr1              0.579382               NaN         0.786327
# Fgfr1              0.579382               NaN         0.786327
# Esrp1                   NaN               NaN              NaN
# Esrp1                   NaN               NaN              NaN
#
#          Nostrils - Tfap2b  Philtrum  Roof - Sim1  Whisker Pad  \
# Dlx5             -2.217777 -1.919984    -2.297477    -1.072130
# Dlx5             -2.217777 -1.919984    -2.297477    -1.072130
# Aldh1a2          -3.803557 -2.889247    -2.601304    -3.193179
# Pax6                   NaN       NaN          NaN          NaN
# Pax6                   NaN       NaN          NaN          NaN
# Hesx1                  NaN       NaN          NaN          NaN
# Pdgfra                 NaN  0.646511          NaN     0.181480
# Sp8                    NaN       NaN          NaN          NaN
# Sp8                    NaN       NaN          NaN          NaN
# Sp8                    NaN       NaN          NaN          NaN
# Shh                    NaN       NaN          NaN          NaN
# Edil3                  NaN -1.116167     1.464274    -0.812293
# Shh                    NaN       NaN          NaN          NaN
# Shh                    NaN       NaN          NaN          NaN
# Dkk1                   NaN       NaN     1.621649     2.415451
# Dlx5             -2.217777 -1.919984    -2.297477    -1.072130
# Gas1              0.719346  1.494225     0.632490     0.562714
# Otx2                   NaN       NaN          NaN          NaN
# Ndst3                  NaN       NaN          NaN     2.527488
# Ndst3                  NaN       NaN          NaN     2.527488
# Shh                    NaN       NaN          NaN          NaN
# Six3                   NaN       NaN          NaN          NaN
# Hesx1                  NaN       NaN          NaN          NaN
# Rdh10                  NaN       NaN          NaN     0.579361
# Rdh10                  NaN       NaN          NaN     0.579361
# Rdh10                  NaN       NaN          NaN     0.579361
# Rdh10                  NaN       NaN          NaN     0.579361
# Rdh10                  NaN       NaN          NaN     0.579361
# Aldh1a2          -3.803557 -2.889247    -2.601304    -3.193179
# Ptch1            -1.600664 -0.443187    -1.189183     0.384249
# Cldn6                  NaN       NaN          NaN          NaN
# Foxg1                  NaN       NaN          NaN          NaN
# Hand1                  NaN       NaN          NaN          NaN
# Tfap2a            1.630658 -1.113659    -1.509677    -1.150169
# Tfap2a            1.630658 -1.113659    -1.509677    -1.150169
# Tfap2a            1.630658 -1.113659    -1.509677    -1.150169
# Foxg1                  NaN       NaN          NaN          NaN
# Fgfr2                  NaN  0.399731     0.884756     1.061445
# Alx1              1.121093  2.500593     0.639201    -0.391202
# Alx4              0.946143  1.300044          NaN     0.497647
# Alx4              0.946143  1.300044          NaN     0.497647
# Alx1              1.121093  2.500593     0.639201    -0.391202
# Fgfr1            -0.340763  0.845733          NaN     0.435496
# Fgfr1            -0.340763  0.845733          NaN     0.435496
# Esrp1                  NaN       NaN          NaN          NaN
# Esrp1                  NaN       NaN          NaN          NaN
#
#          Periocular Mesenchyme
# Dlx5                       NaN
# Dlx5                       NaN
# Aldh1a2               1.237010
# Pax6                       NaN
# Pax6                       NaN
# Hesx1                      NaN
# Pdgfra                     NaN
# Sp8                        NaN
# Sp8                        NaN
# Sp8                        NaN
# Shh                        NaN
# Edil3                      NaN
# Shh                        NaN
# Shh                        NaN
# Dkk1                       NaN
# Dlx5                       NaN
# Gas1                  0.321699
# Otx2                       NaN
# Ndst3                      NaN
# Ndst3                      NaN
# Shh                        NaN
# Six3                       NaN
# Hesx1                      NaN
# Rdh10                      NaN
# Rdh10                      NaN
# Rdh10                      NaN
# Rdh10                      NaN
# Rdh10                      NaN
# Aldh1a2               1.237010
# Ptch1                -0.767689
# Cldn6                      NaN
# Foxg1                      NaN
# Hand1                      NaN
# Tfap2a               -0.685825
# Tfap2a               -0.685825
# Tfap2a               -0.685825
# Foxg1                      NaN
# Fgfr2                -0.556475
# Alx1                       NaN
# Alx4                       NaN
# Alx4                       NaN
# Alx1                       NaN
# Fgfr1                -0.475252
# Fgfr1                -0.475252
# Esrp1                      NaN
# Esrp1                      NaN
#
# [46 rows x 58 columns]

# %%
for stage in list(adata.obs['stage'].cat.categories):
    adata_tmp = adata[adata.obs['stage']==stage]
    adata_tmp = adata_tmp[adata_tmp.obs['annotation_all'].isin(list(adata_tmp.obs['annotation_all'].value_counts()[adata_tmp.obs['annotation_all'].value_counts()>20].index))]
    sc.tl.rank_genes_groups(adata_tmp,groupby = 'annotation_all',
                        method = 'wilcoxon',
                       )
    rank_genes_df = sc.get.rank_genes_groups_df(adata_tmp, group = None)
    rank_genes_df = rank_genes_df[rank_genes_df['names'].isin(list(set(gene_list_org['Marker Symbol'])))]
    rank_genes_df = rank_genes_df[~rank_genes_df['scores'].between(-4, 4)]
    rank_genes_df = rank_genes_df.pivot(index='names', columns='group', values=['logfoldchanges'])
    for gene in list(set(gene_list_org['Marker Symbol']).difference(list(rank_genes_df.index))):
        rank_genes_df.loc[gene] = pd.Series(dtype='float64')
    rank_genes_df.columns = rank_genes_df.columns.droplevel()
    
    lmd_result = pd.read_csv('r_lmd_result_E'+stage+'.txt',index_col = 0)
    lmd_result.rename({'score':'LMD_score'}, axis=1, inplace=True)
    gene_list_stage = gene_list_org.merge(lmd_result, how = 'left',left_index=True, right_index=True)
    del gene_list_stage['rank']
    expanded_table[stage] = gene_list_stage.merge(rank_genes_df, left_index=True, right_index=True)

for stage in list(adata.obs['stage'].cat.categories):
    expanded_table[stage].insert(loc=3, column='Top Cluster', value=list(expanded_table[stage].iloc[:,4:].idxmax(axis=1,skipna=True)))

# %%
with pd.ExcelWriter("GWAS/gwas_table_prominences_expanded_LMD.xlsx") as writer:
    for df_name, df in expanded_table.items():
        df.to_excel(writer, sheet_name=df_name)
